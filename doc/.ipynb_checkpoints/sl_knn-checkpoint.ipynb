# %%
import pandas as pd

# %%
import pyreadr

# %%
result = pyreadr.read_r('../output/mat_fac.rdata') # also works for RData

# %%
result.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8931c1f4f079> in <module>
# ----> 1 result.head()
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'head'

# %%
rmse = pd.read_csv('../data/rmse.csv')

# %%
rmse.head()
# Out:
#    Unnamed: 0 train_test                       par  epoch      RMSE
# 0           1      Train  f =  10 , lambda =  0.01      1  0.825492
# 1           2      Train  f =  20 , lambda =  0.01      1  0.792257
# 2           3      Train   f =  10 , lambda =  0.1      1  0.896950
# 3           4      Train   f =  20 , lambda =  0.1      1  0.859586
# 4           5       Test  f =  10 , lambda =  0.01      1  1.313171

# %%
rmse.tail()
# Out:
#     Unnamed: 0 train_test                       par  epoch      RMSE
# 75          76      Train   f =  20 , lambda =  0.1     10  0.533895
# 76          77       Test  f =  10 , lambda =  0.01     10  1.299296
# 77          78       Test  f =  20 , lambda =  0.01     10  1.421808
# 78          79       Test   f =  10 , lambda =  0.1     10  1.165586
# 79          80       Test   f =  20 , lambda =  0.1     10  1.217462

# %%
rmse
# Out:
#     Unnamed: 0 train_test                       par  epoch      RMSE
# 0            1      Train  f =  10 , lambda =  0.01      1  0.825492
# 1            2      Train  f =  20 , lambda =  0.01      1  0.792257
# 2            3      Train   f =  10 , lambda =  0.1      1  0.896950
# 3            4      Train   f =  20 , lambda =  0.1      1  0.859586
# 4            5       Test  f =  10 , lambda =  0.01      1  1.313171
# 5            6       Test  f =  20 , lambda =  0.01      1  1.456230
# 6            7       Test   f =  10 , lambda =  0.1      1  1.289641
# 7            8       Test   f =  20 , lambda =  0.1      1  1.384565
# 8            9      Train  f =  10 , lambda =  0.01      2  0.709165
# 9           10      Train  f =  20 , lambda =  0.01      2  0.657109
# 10          11      Train   f =  10 , lambda =  0.1      2  0.770602
# 11          12      Train   f =  20 , lambda =  0.1      2  0.722461
# 12          13       Test  f =  10 , lambda =  0.01      2  1.269319
# ...
